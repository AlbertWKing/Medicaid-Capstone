# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy import create_engine
import warnings
# DANGER DANGER DANGER
warnings.filterwarnings("ignore")
# DANGER DANGER DANGER
my_username = "root"
my_password = "rootroot"
schema_name = "med"
engine = db.create_engine(f"mysql+pymysql://{my_username}:{my_password}@localhost/{schema_name}", echo=False)
conn = engine.connect()

# %%
features = "state, ndc, labeler_code, product_code, package_size, year, quarter, product_name, units_reimbursed, number_of_prescriptions, total_amount_reimbursed"

# %%
features = "product_name, ndc, labeler_code, product_code, package_size, number_of_prescriptions, units_reimbursed, total_amount_reimbursed, state, year, quarter"
table = "d93"
df = pd.read_sql(f"SELECT {features} FROM {table} WHERE number_of_prescriptions != 0 LIMIT 10;", conn)
df
# Out:
#   product_name          ndc  labeler_code  product_code  package_size  \
# 0   DARVON-N    00002035302             2           353             2
# 1   DARVOCET-N  00002036302             2           363             2
# 2   DARVOCET-N  00002036303             2           363             3
# 3   SECONAL SO  00002064002             2           640             2
# 4   DARVON      00002080302             2           803             2
# 5   AVENTYL HC  00002081933             2           819            33
# 6   PHENOBARBI  00002103202             2          1032             2
# 7   PHENOBARBI  00002103302             2          1033             2
# 8   PHENOBARBI  00002103702             2          1037             2
# 9   PHENOBARBI  00002243805             2          2438             5
#
#    number_of_prescriptions  units_reimbursed  total_amount_reimbursed state  \
# 0                       13               931                      496    AK
# ...

# %%
features = "product_name, ndc, labeler_code, product_code, package_size, number_of_prescriptions, units_reimbursed, total_amount_reimbursed, state, year, quarter"
table = "d93"
df = pd.read_sql(f"SELECT {features} FROM {table} WHERE ndc REGEXP '01210531' LIMIT 10;", conn)
df
# Out:
#   product_name          ndc  labeler_code  product_code  package_size  \
# 0   PHENOBARBI  00121053105           121           531             5
# 1   PHENOBARBI  00121053105           121           531             5
# 2   PHENOBARBI  00121053105           121           531             5
# 3   PHENOBARBI  00121053105           121           531             5
# 4   PHENOBARBI  00121053107           121           531             7
# 5   PHENOBARBI  00121053107           121           531             7
# 6   PHENOBARBI  00121053107           121           531             7
# 7   PHENOBARBI  00121053107           121           531             7
# 8   PHENOBARBI  00121053107           121           531             7
# 9   PHENOBARBI  00121053105           121           531             5
#
#    number_of_prescriptions  units_reimbursed  total_amount_reimbursed state  \
# 0                        0                 0                        0    GA
# ...

# %%
features = "ndc, count(*)"
table = "d21"
drug = 'PHENOBARBI'
where = f"product_name REGEXP '^{drug}'"
df = pd.read_sql(f"SELECT {features} FROM {table} WHERE {where} GROUP BY ndc;", conn)
df
# Out:
#              ndc  count(*)
# 0    00603150858       307
# 1    00603516521       214
# 2    00603516621       286
# 3    00603516721       302
# 4    00603516821       268
# ..           ...       ...
# 105  75826014100         4
# 106  00143144501         4
# 107  63739020110         3
# 108  60687044840         2
# 109  75826013900         2
#
# [110 rows x 2 columns]

# %%
features = "*"
table = "ndc"
df = pd.read_sql(f"SELECT {features} FROM {table} LIMIT 10;", conn)
df

# %%
features = "*"
table = "ndc"
drug = 'PHENOBARBI'
where = f"SUBSTANCENAME REGEXP '^{drug}'"
df = pd.read_sql(f"SELECT {features} FROM {table} WHERE {where} LIMIT 20;", conn)
df
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0121-0531_d4dbd9ed-e7bc-038e-e053-2a95a90a8a27  0121-0531
# 1  0121-0942_cae1f392-4081-90f9-e053-2a95a90a8fb5  0121-0942
# 2  0121-1884_cae1f392-4081-90f9-e053-2a95a90a8fb5  0121-1884
# 3  0121-2826_cae1f392-4081-90f9-e053-2a95a90a8fb5  0121-2826
# 4  0143-1455_8b0f0d64-752d-4827-8455-e3b3c90ff849  0143-1455
# 5  0143-1458_8b0f0d64-752d-4827-8455-e3b3c90ff849  0143-1458
# 6  0143-1495_8b0f0d64-752d-4827-8455-e3b3c90ff849  0143-1495
# 7  0143-1500_8b0f0d64-752d-4827-8455-e3b3c90ff849  0143-1500
#
#            PRODUCTTYPENAME              PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0  HUMAN PRESCRIPTION DRUG                Phenobarbital
# 1  HUMAN PRESCRIPTION DRUG  Phenobarbital Oral Solution
# 2  HUMAN PRESCRIPTION DRUG  Phenobarbital Oral Solution
# 3  HUMAN PRESCRIPTION DRUG  Phenobarbital Oral Solution
# 4  HUMAN PRESCRIPTION DRUG                Phenobarbital
# ...

# %%
features = "ndc, product_name, count(*)"
table = "d93"
drug = 'PHENOBARBI'
where = f"product_name REGEXP '^{drug}' AND number_of_prescriptions != 0"
df_med = pd.read_sql(f"SELECT {features} FROM {table} WHERE {where} GROUP BY ndc, product_name;", conn)
df_med
# Out:
#              ndc product_name  count(*)
# 0    00002103202   PHENOBARBI       192
# 1    00002103302   PHENOBARBI       194
# 2    00002103702   PHENOBARBI       198
# 3    00002243805   PHENOBARBI       191
# 4    00047060732   PHENOBARBI       191
# ..           ...          ...       ...
# 170  00071069840   PHENOBARBI         3
# 171  00071060740   PHENOBARBI         1
# 172  00071070032   PHENOBARBI         2
# 173  00008030401   PHENOBARBI         3
# 174  00005326234   PHENOBARBI         1
#
# [175 rows x 3 columns]

# %%
code = df_med['ndc'][0]
print(code)
first = code[-10:-6]
second = code[-6:-2]
print(first)
print(second)

# %%
features = "*"
table = "ndc"
drug = 'PHENOBARBI'

for code in df_med['ndc']:
    first = code[-10:-6]
    second = code[-6:-2]
    where = f"PRODUCTNDC REGEXP '{first}-{second}'"
    df_ndc = pd.read_sql(f"SELECT {features} FROM {table} WHERE {where} LIMIT 20;", conn)
    if df_ndc.empty == False:
        display(df_ndc)
# Out:
#                                         PRODUCTID PRODUCTNDC  \
# 0  0121-0531_d4dbd9ed-e7bc-038e-e053-2a95a90a8a27  0121-0531
#
#            PRODUCTTYPENAME PROPRIETARYNAME PROPRIETARYNAMESUFFIX  \
# 0  HUMAN PRESCRIPTION DRUG   Phenobarbital
#
#   NONPROPRIETARYNAME DOSAGEFORMNAME ROUTENAME STARTMARKETINGDATE  \
# 0      Phenobarbital       SOLUTION      ORAL         2007-02-19
#
#   ENDMARKETINGDATE  MARKETINGCATEGORYNAME APPLICATIONNUMBER  \
# 0                   UNAPPROVED DRUG OTHER
#
#                        LABELERNAME  SUBSTANCENAME ACTIVE_NUMERATOR_STRENGTH  \
# 0  Pharmaceutical Associates, Inc.  PHENOBARBITAL                        20
#
#   ACTIVE_INGRED_UNIT PHARM_CLASSES DEASCHEDULE NDC_EXCLUDE_FLAG  \
# 0             mg/5mL                       CIV                N
#
#   LISTING_RECORD_CERTIFIED_THROUGH
# 0                       2023-12-31
#                                         PRODUCTID PRODUCTNDC  \
# 0  0121-0531_d4dbd9ed-e7bc-038e-e053-2a95a90a8a27  0121-0531
# ...

# %%
# df_med['ndc']=df_med['ndc'][:-2]

for ind in df_med.index:
    df_med.loc[ind,'ndc'] = (df_med.loc[ind,'ndc'])[:-2]
# Out:
#            ndc product_name  count(*)
# 0    000021032   PHENOBARBI       192
# 1    000021033   PHENOBARBI       194
# 2    000021037   PHENOBARBI       198
# 3    000022438   PHENOBARBI       191
# 4    000470607   PHENOBARBI       191
# ..         ...          ...       ...
# 170  000710698   PHENOBARBI         3
# 171  000710607   PHENOBARBI         1
# 172  000710700   PHENOBARBI         2
# 173  000080304   PHENOBARBI         3
# 174  000053262   PHENOBARBI         1
#
# [175 rows x 3 columns]

# %%
len(df_med['ndc'].unique())
# Out:
# 127
